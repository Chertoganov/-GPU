# %%
#Download the required libraries
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import matplotlib.pyplot as plt
import torchvision
from torchvision import datasets, models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torch.onnx
import torchvision

# %matplotlib inline

plt.ion()   # interactive mode

# %% [markdown]
# **ЗАГРУЗКА ДАННЫХ**

# %%
#Получаю адрес папки /content (папка диска)
dir = os.path.abspath(os.curdir)
# указываем путь до датасета 
data_dir=os.path.join(dir, "DATASET")

# Масштабируем данные до 224*224 и нормализуем для train и test
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
}

#Создаю функцию для загрузки изображений из датасета и ресайза для модели Create function to get your(my) images dataset and resize it to size for model
def get_dataset(data_dir, data_transforms):

    # Создаю train и test датасеты
    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                              data_transforms[x])
                      for x in ['train', 'test']}
    dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                                 shuffle=True, num_workers=4)
                  for x in ['train', 'test']}
    dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
    #Получаем классы из имен папок train датасета
    classes = image_datasets['train'].classes

    return dataloaders["train"], dataloaders['test'], classes, dataset_sizes

# %%
# Загружаем данные train и test
trainloader, testloader, classes, dataset_sizes=get_dataset(data_dir,data_transforms)
print('Классов: ',  classes)
print('Набор данных содержит: ',  dataset_sizes ," снимков")
# Out:
# Классов:  ['0', '2', '3', '4', '5']
# Набор данных содержит:  {'train': 189, 'test': 41}  снимков

# %% [markdown]
# **ПРЕДПОДГОТОВКА ИЗОБРАЖЕНИЙ**

# %%
# Функция для создания нового изображения после трансформации 
def imshow_DenseNet(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # пауза для обновления графика

# %% [markdown]
# **СОЗДАНИЕ МОДЕЛИ**

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Каждая эпоха имеет свою фазу обучения и проверки
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Перебираем данные
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Обнуляем градиент
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + оптимизатор только в тренировочной фазе
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # статистика
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
dataloaders = {'train': trainloader, 'test': testloader}
# model_ft = models.resnet18(pretrained=True) - было
model_ft = torch.hub.load('pytorch/vision:v0.6.0', 'densenet121', pretrained=True)
num_ftrs = model_ft.classifier.in_features
# Здесь размер каждого выходного образца устанавливается равным числу классов.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.classifier = nn.Sequential(nn.Linear(num_ftrs, 256), 
                                    nn.ReLU(), 
                                    nn.Dropout(0.4), 
                                    nn.Linear(256, len(classes))) 

device = 'cuda'
model_ft = model_ft.to(device)

model_ft = torch.nn.DataParallel(model_ft) # Магия параллелизма на нескоьких GPU

criterion = nn.CrossEntropyLoss()

# Оптимизируем все параметры
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Снижение LR каждые 7 эпох 
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-16ba29c2e464> in <module>
# ----> 1 dataloaders = {'train': trainloader, 'test': testloader}
#       2 # model_ft = models.resnet18(pretrained=True) - было
#       3 model_ft = torch.hub.load('pytorch/vision:v0.6.0', 'densenet121', pretrained=True)
#       4 num_ftrs = model_ft.classifier.in_features
#       5 # Здесь размер каждого выходного образца устанавливается равным числу классов.
#
# NameError: name 'trainloader' is not defined

# %% [markdown]
# **ОБУЧЕНИЕ МОДЕЛИ**

# %%
#Train the model
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=50)
# Out:
# Epoch 0/49
# ----------
# train Loss: 1.5653 Acc: 0.2857
# test Loss: 1.8114 Acc: 0.1463
#
# Epoch 1/49
# ----------
# train Loss: 1.4965 Acc: 0.3228
# test Loss: 1.6440 Acc: 0.1951
#
# Epoch 2/49
# ----------
# train Loss: 1.5065 Acc: 0.3545
# test Loss: 1.6412 Acc: 0.1707
#
# Epoch 3/49
# ----------
# train Loss: 1.5068 Acc: 0.3280
# test Loss: 1.6990 Acc: 0.1951
#
# Epoch 4/49
# ----------
# train Loss: 1.4883 Acc: 0.3175
# test Loss: 1.7750 Acc: 0.1951
#
# Epoch 5/49
# ----------
# train Loss: 1.4912 Acc: 0.3492
# test Loss: 1.7468 Acc: 0.1951
#
# Epoch 6/49
# ----------
# train Loss: 1.5015 Acc: 0.3122
# test Loss: 1.6308 Acc: 0.1951
#
# Epoch 7/49
# ----------
# train Loss: 1.5040 Acc: 0.3333
# test Loss: 1.6331 Acc: 0.1951
#
# Epoch 8/49
# ----------
# train Loss: 1.4842 Acc: 0.3439
# test Loss: 1.6431 Acc: 0.1951
#
# Epoch 9/49
# ----------
# train Loss: 1.4530 Acc: 0.3651
# test Loss: 1.6813 Acc: 0.1951
#
# Epoch 10/49
# ----------
# train Loss: 1.4830 Acc: 0.3228
# test Loss: 1.7013 Acc: 0.1951
#
# Epoch 11/49
# ----------
# train Loss: 1.4712 Acc: 0.3439
# test Loss: 1.7214 Acc: 0.1951
#
# Epoch 12/49
# ----------
# train Loss: 1.4630 Acc: 0.3545
# test Loss: 1.7011 Acc: 0.2195
#
# Epoch 13/49
# ----------
# train Loss: 1.4470 Acc: 0.3545
# test Loss: 1.7047 Acc: 0.1951
#
# Epoch 14/49
# ----------
# train Loss: 1.4618 Acc: 0.3228
# test Loss: 1.7160 Acc: 0.1951
#
# Epoch 15/49
# ----------
# train Loss: 1.4586 Acc: 0.3545
# test Loss: 1.7150 Acc: 0.1951
#
# Epoch 16/49
# ----------
# train Loss: 1.4611 Acc: 0.3492
# test Loss: 1.7220 Acc: 0.1951
#
# Epoch 17/49
# ----------
# train Loss: 1.4478 Acc: 0.3757
# test Loss: 1.7055 Acc: 0.1951
#
# Epoch 18/49
# ----------
# train Loss: 1.4394 Acc: 0.3810
# test Loss: 1.7199 Acc: 0.1951
#
# Epoch 19/49
# ----------
# train Loss: 1.4570 Acc: 0.3175
# test Loss: 1.7059 Acc: 0.2195
#
# Epoch 20/49
# ----------
# train Loss: 1.4558 Acc: 0.3386
# test Loss: 1.7260 Acc: 0.1951
#
# Epoch 21/49
# ----------
# train Loss: 1.4577 Acc: 0.3598
# test Loss: 1.7216 Acc: 0.1951
#
# Epoch 22/49
# ----------
# train Loss: 1.4470 Acc: 0.3651
# test Loss: 1.7246 Acc: 0.1951
#
# Epoch 23/49
# ----------
# train Loss: 1.4500 Acc: 0.3439
# test Loss: 1.7325 Acc: 0.1951
#
# Epoch 24/49
# ----------
# train Loss: 1.4468 Acc: 0.3492
# test Loss: 1.7211 Acc: 0.1951
#
# Epoch 25/49
# ----------
# train Loss: 1.4533 Acc: 0.3598
# test Loss: 1.7020 Acc: 0.1951
#
# Epoch 26/49
# ----------
# train Loss: 1.4681 Acc: 0.3386
# test Loss: 1.7199 Acc: 0.1951
#
# Epoch 27/49
# ----------
# train Loss: 1.4512 Acc: 0.3598
# test Loss: 1.7311 Acc: 0.2195
#
# Epoch 28/49
# ----------
# train Loss: 1.4375 Acc: 0.3862
# test Loss: 1.7153 Acc: 0.1951
#
# Epoch 29/49
# ----------
# train Loss: 1.4498 Acc: 0.3704
# test Loss: 1.7185 Acc: 0.1951
#
# Epoch 30/49
# ----------
# train Loss: 1.4558 Acc: 0.3386
# test Loss: 1.7478 Acc: 0.1951
#
# Epoch 31/49
# ----------
# train Loss: 1.4569 Acc: 0.3598
# test Loss: 1.7169 Acc: 0.1951
#
# Epoch 32/49
# ----------
# train Loss: 1.4564 Acc: 0.3704
# test Loss: 1.7314 Acc: 0.1951
#
# Epoch 33/49
# ----------
# train Loss: 1.4470 Acc: 0.3810
# test Loss: 1.7161 Acc: 0.1951
#
# Epoch 34/49
# ----------
# train Loss: 1.4539 Acc: 0.3439
# test Loss: 1.7173 Acc: 0.1951
#
# Epoch 35/49
# ----------
# train Loss: 1.4364 Acc: 0.3492
# test Loss: 1.7196 Acc: 0.1951
#
# Epoch 36/49
# ----------
# train Loss: 1.4497 Acc: 0.3492
# test Loss: 1.7289 Acc: 0.1951
#
# Epoch 37/49
# ----------
# train Loss: 1.4442 Acc: 0.3492
# test Loss: 1.7249 Acc: 0.1951
#
# Epoch 38/49
# ----------
# train Loss: 1.4585 Acc: 0.3439
# test Loss: 1.7384 Acc: 0.1951
#
# Epoch 39/49
# ----------
# train Loss: 1.4389 Acc: 0.3439
# test Loss: 1.7293 Acc: 0.1951
#
# Epoch 40/49
# ----------
# train Loss: 1.4648 Acc: 0.3386
# test Loss: 1.7416 Acc: 0.1951
#
# Epoch 41/49
# ----------
# train Loss: 1.4690 Acc: 0.3439
# test Loss: 1.7343 Acc: 0.1951
#
# Epoch 42/49
# ----------
# train Loss: 1.4455 Acc: 0.3651
# test Loss: 1.7142 Acc: 0.1951
#
# Epoch 43/49
# ----------
# train Loss: 1.4693 Acc: 0.3280
# test Loss: 1.7240 Acc: 0.1951
#
# Epoch 44/49
# ----------
# train Loss: 1.4492 Acc: 0.3704
# test Loss: 1.7051 Acc: 0.1951
#
# Epoch 45/49
# ----------
# train Loss: 1.4730 Acc: 0.3069
# test Loss: 1.7229 Acc: 0.1951
#
# Epoch 46/49
# ----------
# train Loss: 1.4512 Acc: 0.3598
# test Loss: 1.6977 Acc: 0.2195
#
# Epoch 47/49
# ----------
# train Loss: 1.4506 Acc: 0.3492
# test Loss: 1.7366 Acc: 0.1951
#
# Epoch 48/49
# ----------
# train Loss: 1.4529 Acc: 0.3228
# test Loss: 1.7262 Acc: 0.1951
#
# Epoch 49/49
# ----------
# train Loss: 1.4561 Acc: 0.3492
# test Loss: 1.7248 Acc: 0.1951
#
# Training complete in 43m 39s
# Best val Acc: 0.219512

# %% [markdown]
# **РЕЗУЛЬТАТЫ МОДЕЛИ**

# %%
# Визуализируем результаты
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.cuda(), labels.cuda()
        outputs = model_ft(images)
        _, predicted = torch.max(outputs.data, 1)
        
        for printdata in list(zip(predicted,labels,outputs)):
            printclass =[classes[int(printdata[0])],classes[int(printdata[1])]]
            print('Predict class - {0}, real class - {1}, probability ({2},{3}) - {4}'.format( printclass[0],printclass[1],
                                                                              classes[0], classes [1],printdata[2]))

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        # imshow_DenseNet(torchvision.utils.make_grid(images))
        #print('GroundTruth: ', ' '.join('%5s' % classes[predicted[j]] for j in range(4)))
print('Accuracy of the network on the', dataset_sizes['test'], 'test images: %d %%' % (
    100 * correct / total))
# Out:
# Predict class - 2, real class - 0, probability (0,2) - tensor([-0.6284,  0.4675, -0.1282,  0.4590,  0.1947], device='cuda:0')
# Predict class - 4, real class - 2, probability (0,2) - tensor([-0.6454,  0.3062, -0.0745,  0.4121,  0.0049], device='cuda:0')
# Predict class - 2, real class - 3, probability (0,2) - tensor([-0.7814,  0.4678, -0.0424,  0.4316,  0.0075], device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-0.8019,  0.4400, -0.0931,  0.5725, -0.0546], device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-0.8369,  0.4122, -0.1063,  0.5873, -0.0555], device='cuda:0')
# Predict class - 2, real class - 2, probability (0,2) - tensor([-0.6609,  0.4966, -0.0399,  0.4633, -0.0056], device='cuda:0')
# Predict class - 4, real class - 2, probability (0,2) - tensor([-0.8048,  0.4505, -0.1365,  0.4953, -0.0204], device='cuda:0')
# Predict class - 4, real class - 2, probability (0,2) - tensor([-0.8835,  0.4635, -0.1303,  0.5236,  0.0615], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-1.1036,  0.6143,  0.0150,  0.6349,  0.0366], device='cuda:0')
# Predict class - 4, real class - 0, probability (0,2) - tensor([-0.9820,  0.6225, -0.0807,  0.6336,  0.0891], device='cuda:0')
# Predict class - 4, real class - 0, probability (0,2) - tensor([-0.8026,  0.4129, -0.1390,  0.4591,  0.1571], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-1.0762,  0.5874, -0.0771,  0.7982,  0.0618], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.8752,  0.4444, -0.0129,  0.4543, -0.0300], device='cuda:0')
# Predict class - 2, real class - 3, probability (0,2) - tensor([-0.8495,  0.5489, -0.0815,  0.5452,  0.0461], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-1.0715,  0.5259, -0.0050,  0.5892,  0.0142], device='cuda:0')
# Predict class - 4, real class - 0, probability (0,2) - tensor([-1.0377,  0.4757,  0.0223,  0.7072,  0.1212], device='cuda:0')
# Predict class - 2, real class - 3, probability (0,2) - tensor([-0.7063,  0.4058, -0.0778,  0.3674,  0.0991], device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-0.7835,  0.3997, -0.0685,  0.6102,  0.0345], device='cuda:0')
# Predict class - 4, real class - 2, probability (0,2) - tensor([-0.9924,  0.4690, -0.1741,  0.6947, -0.0339], device='cuda:0')
# Predict class - 2, real class - 3, probability (0,2) - tensor([-1.1160e+00,  7.2570e-01, -2.3058e-02,  6.8109e-01,  8.2838e-04],
#        device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-7.0869e-01,  3.7869e-01,  2.9002e-02,  4.8759e-01, -6.1668e-05],
#        device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.7988,  0.4844, -0.0305,  0.4925,  0.0039], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.7939,  0.3921, -0.0702,  0.5172,  0.0037], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.8217,  0.4267, -0.0786,  0.5321,  0.0099], device='cuda:0')
# Predict class - 2, real class - 3, probability (0,2) - tensor([-0.4614,  0.3798, -0.0742,  0.3667,  0.1780], device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-0.7080,  0.3339, -0.1432,  0.4165,  0.0252], device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-0.5567,  0.3537,  0.0384,  0.4394, -0.0592], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.6517,  0.4144,  0.0343,  0.5871,  0.0738], device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-0.8273,  0.3828, -0.0834,  0.5392,  0.0047], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.6539,  0.4328, -0.0466,  0.5435,  0.0533], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.6973,  0.4115, -0.0103,  0.5030, -0.0409], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.7989,  0.4661, -0.0102,  0.5152, -0.0319], device='cuda:0')
# Predict class - 2, real class - 3, probability (0,2) - tensor([-0.7833,  0.5367, -0.0254,  0.5209,  0.1543], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.7220,  0.2820, -0.0077,  0.5125,  0.0337], device='cuda:0')
# Predict class - 2, real class - 3, probability (0,2) - tensor([-0.7231,  0.6274, -0.0243,  0.4611,  0.0429], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.9551,  0.5419, -0.0705,  0.7747,  0.0124], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.7963,  0.4406, -0.0122,  0.5313,  0.0370], device='cuda:0')
# Predict class - 4, real class - 4, probability (0,2) - tensor([-0.7089,  0.4260,  0.0171,  0.4908, -0.0021], device='cuda:0')
# Predict class - 4, real class - 2, probability (0,2) - tensor([-0.9171,  0.5949, -0.0607,  0.6552,  0.0761], device='cuda:0')
# Predict class - 4, real class - 0, probability (0,2) - tensor([-0.8455,  0.4345, -0.0932,  0.5238,  0.0501], device='cuda:0')
# Predict class - 4, real class - 3, probability (0,2) - tensor([-0.6072,  0.3480, -0.0045,  0.4232,  0.0130], device='cuda:0')
# Accuracy of the network on the 41 test images: 21 %

# %% [markdown]
# **СОХРАНЯЕМ МОДЕЛЬ**

# %%
# Сохраним обученную модель
dir=''
PATH =os.path.join(dir, "model v0.1(CT)K")
torch.save(model_ft, PATH)

# %% [markdown]
# **ИСПОЛЬЗУЕМ ОБУЧЕННУЮ МОДЕЛЬ ДЛЯ ПРЕДСКАЗАНИЙ НА РАБОЧИХ ДАННЫХ**

# %%
modelBR=torch.load('model v0.1(CT)K')

# %%
dir=''
PATH = os.path.join(dir, "modelKK.pt")
torch.save(modelBR.state_dict(), PATH)

# %% [markdown]
# Загружаем и преобразуем изображение в модель

# %%
path_file = 'DATASET'
transforms_file = transforms.Compose([transforms.Resize(256), transforms.CenterCrop(224), transforms.ToTensor(),transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])
image_datasets = datasets.ImageFolder(os.path.join(path_file,'test'), transforms_file)
workloader2 = torch.utils.data.DataLoader(image_datasets, batch_size=1, shuffle=True, num_workers=4)

# %%
# !ls
# Out:
# bi-rads-classifier		     DATASET-20200616T230435Z-005.zip
# bi-rads-classifier.rar		     modelKK.pt
# BI_RADS_Classifier_v0_2_2(CT).ipynb  model v0.1(CT)K
# DATASET

# %%
# Предсказываем класс
classes_test = ['0', '1', '2', '3', '4', '5']
with torch.no_grad():
    for data in workloader2:
        images, labels = data
        images, labels = images.cuda(), labels.cuda()
        outputs = modelBR(images)
        _, predicted = torch.max(outputs.data, 1)
        for printdata in list(zip(predicted,labels,outputs)):
            printclass =[classes_test[int(printdata[0])],classes_test[int(printdata[1])]]
            print(u'Предсказанный класс по классификации BI-RADS - {0}'.format(printclass[0]))
# Out:
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 1
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
# Предсказанный класс по классификации BI-RADS - 3
